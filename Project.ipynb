# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import accuracy_score
import numpy as np

# %% [markdown]
# ## data exploration

# %%
df = pd.read_csv("./final_combined_dataset.csv")

# %%
df.head()
# Out:
#      T01    H01    T02    H02    T11    H11    T12    H12    T21    H21  \
# 0  30.21  43.82  30.16  43.05  30.20  43.79  30.17  43.05  30.19  43.79
# 1  30.20  43.79  30.17  43.05  30.19  43.79  30.17  43.05  30.19  43.79
# 2  30.19  43.79  30.17  43.05  30.19  43.79  30.19  43.12  30.19  43.79
# 3  30.19  43.79  30.19  43.12  30.19  43.79  30.18  43.09  30.19  43.79
# 4  30.19  43.79  30.18  43.09  30.19  43.79  30.18  43.09  30.19  43.79
#
#      T22    H22  Label Fault Type  Beta
# 0  30.17  43.05      1   Stuck-at   NaN
# 1  30.19  43.12      1   Stuck-at   NaN
# 2  30.18  43.09      1   Stuck-at   NaN
# 3  30.18  43.09      1   Stuck-at   NaN
# 4  30.18  43.09      1   Stuck-at   NaN

# %%
df2 = df.drop(columns=['Fault Type', 'Beta'])

# %%
df2.head()
# Out:
#      T01    H01    T02    H02    T11    H11    T12    H12    T21    H21  \
# 0  30.21  43.82  30.16  43.05  30.20  43.79  30.17  43.05  30.19  43.79
# 1  30.20  43.79  30.17  43.05  30.19  43.79  30.17  43.05  30.19  43.79
# 2  30.19  43.79  30.17  43.05  30.19  43.79  30.19  43.12  30.19  43.79
# 3  30.19  43.79  30.19  43.12  30.19  43.79  30.18  43.09  30.19  43.79
# 4  30.19  43.79  30.18  43.09  30.19  43.79  30.18  43.09  30.19  43.79
#
#      T22    H22  Label
# 0  30.17  43.05      1
# 1  30.19  43.12      1
# 2  30.18  43.09      1
# 3  30.18  43.09      1
# 4  30.18  43.09      1

# %%
df2.shape
# Out:
# (276592, 13)

# %%
df2.describe()
# Out:
#                  T01            H01            T02            H02  \
# count  276592.000000  276592.000000  276592.000000  276592.000000
# mean       33.185460      69.061227      33.041942      70.859195
# std        29.976209      54.472097      27.925101      73.291797
# min        26.290000      43.790000      26.410000      42.850000
# 25%        27.210000      49.480000      27.360000      48.680000
# 50%        28.120000      65.070000      28.350000      61.760000
# 75%        28.850000      69.280000      29.260000      68.560000
# max       300.700000     601.300000     281.300000     723.600000
#
#                  T11            H11            T12            H12  \
# count  276592.000000  276592.000000  276592.000000  276592.000000
# mean       33.184632      69.067488      33.041144      70.865693
# std        29.976345      54.470882      27.925237      73.290681
# min        26.290000      43.790000      26.410000      42.850000
# 25%        27.210000      49.480000      27.357500      48.680000
# 50%        28.120000      65.070000      28.350000      61.760000
# 75%        28.850000      69.280000      29.260000      68.567500
# max       300.700000     601.300000     281.300000     723.600000
#
#                  T21            H21            T22            H22  \
# count  276592.000000  276592.000000  276592.000000  276592.000000
# mean       33.183809      69.073751      33.040347      70.872190
# std        29.976480      54.469663      27.925372      73.289565
# min        26.290000      43.790000      26.410000      42.850000
# 25%        27.210000      49.480000      27.350000      48.680000
# 50%        28.120000      65.070000      28.350000      61.760000
# 75%        28.850000      69.280000      29.260000      68.590000
# max       300.700000     601.300000     281.300000     723.600000
#
#                Label
# count  276592.000000
# mean        0.392549
# std         0.919733
# min        -1.000000
# 25%        -1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
df2.isna().sum()
# Out:
# T01      0
# H01      0
# T02      0
# H02      0
# T11      0
# H11      0
# T12      0
# H12      0
# T21      0
# H21      0
# T22      0
# H22      0
# Label    0
# dtype: int64

# %%
df2.shape
# Out:
# (276592, 13)

# %% [markdown]
# ## preprocessing

# %%
plt.figure(figsize=(15,10))
df2.boxplot()
plt.xticks(rotation=45)
plt.title("Boxplot for outlier detection")
plt.show()

# %%
Q1 =  df2.quantile(0.25)
Q3 = df2.quantile(0.75)
IQR = Q3 - Q1

# %%
outliers = ((df2 < (Q1 - 1.5 * IQR))| (df2 >(Q3 + 1.5*IQR)))

# %%
outliers.sum()
# Out:
# T01      20763
# H01      10442
# T02      17488
# H02      10442
# T11      20763
# H11      10442
# T12      17488
# H12      10442
# T21      20763
# H21      10442
# T22      17488
# H22      10442
# Label        0
# dtype: int64

# %%
rows_with_outliers = outliers.any(axis=1)

# %%
df3 = df2[~rows_with_outliers]

# %%
plt.figure(figsize=(15,10))
df3.boxplot()
plt.xticks(rotation=45)
plt.title("Boxplot After Removing the  Outliers ")
plt.show()

# %%
df3.shape
# Out:
# (217001, 13)

# %%
df2.shape[0],df3.shape[0]
# Out:
# (276592, 217001)

# %%
df3['Label'].value_counts()
# Out:
# Label
#  1    191611
# -1     25390
# Name: count, dtype: int64

# %%
df3['Label'] = df3['Label'].map({1: 0, -1: 1})

# %%
df3.head()
# Out:
#      T01    H01    T02    H02    T11    H11    T12    H12    T21    H21  \
# 0  30.21  43.82  30.16  43.05  30.20  43.79  30.17  43.05  30.19  43.79
# 1  30.20  43.79  30.17  43.05  30.19  43.79  30.17  43.05  30.19  43.79
# 2  30.19  43.79  30.17  43.05  30.19  43.79  30.19  43.12  30.19  43.79
# 3  30.19  43.79  30.19  43.12  30.19  43.79  30.18  43.09  30.19  43.79
# 4  30.19  43.79  30.18  43.09  30.19  43.79  30.18  43.09  30.19  43.79
#
#      T22    H22  Label
# 0  30.17  43.05      0
# 1  30.19  43.12      0
# 2  30.18  43.09      0
# 3  30.18  43.09      0
# 4  30.18  43.09      0

# %%
df3.Label.value_counts()
# Out:
# Label
# 0    191611
# 1     25390
# Name: count, dtype: int64

# %% [markdown]
# ## Train the model

# %%
x = df3.drop(columns=['Label'])
y = df3.Label

# %%
x.shape
# Out:
# (217001, 12)

# %%
y.shape
# Out:
# (217001,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Adjust class Weights

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)

class_weights_dict = dict(enumerate(class_weights))

print(class_weights_dict)
# Out:
# {0: 0.5663799966069402, 1: 4.266194829450506}

# %%
scaler = StandardScaler()

X_trained_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (173600, 12)

# %%
X_trained_scaled.shape
# Out:
# (173600, 12)

# %%
y_train.shape
# Out:
# (173600,)

# %% [markdown]
# ## Network layer

# %% [markdown]
# ## ANN

# %%
model = Sequential([
    Dense(128, activation='relu',input_shape=(X_trained_scaled.shape[1],)),
    Dropout(0.3),
    Dense(64,activation="relu"),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
    
])

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_trained_scaled,y_train,epochs=3,class_weight=class_weights_dict)
# Out:
# Epoch 1/3
# 5425/5425 [==============================] - 10s 2ms/step - loss: 0.0518 - accuracy: 0.9842
# Epoch 2/3
# 5425/5425 [==============================] - 10s 2ms/step - loss: 0.0125 - accuracy: 0.9967
# Epoch 3/3
# 5425/5425 [==============================] - 9s 2ms/step - loss: 0.0114 - accuracy: 0.9973

# %%
loss, acc = model.evaluate(X_test_scaled,y_test)
# Out:
# 1357/1357 [==============================] - 2s 1ms/step - loss: 0.0034 - accuracy: 0.9996

# %%
X_train_rnn = X_trained_scaled.reshape(X_trained_scaled.shape[0], 3, 4)  # (samples, time steps, features)
X_test_rnn = X_test_scaled.reshape(X_test_scaled.shape[0], 3, 4)

# %% [markdown]
# ## LSTM

# %%
model = Sequential([
    LSTM(128, activation='tanh', input_shape=(3, 4), return_sequences=True),
    Dropout(0.3),
    LSTM(64, activation='tanh'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train_rnn, y_train, epochs=3,class_weight=class_weights_dict)
# Out:
# Epoch 1/3
# 5425/5425 [==============================] - 35s 6ms/step - loss: 0.0423 - accuracy: 0.9825
# Epoch 2/3
# 5425/5425 [==============================] - 33s 6ms/step - loss: 0.0149 - accuracy: 0.9972
# Epoch 3/3
# 5425/5425 [==============================] - 35s 7ms/step - loss: 0.0112 - accuracy: 0.9972

# %%
loss, acc = model.evaluate(X_test_rnn,y_test)
# Out:
# 1357/1357 [==============================] - 5s 3ms/step - loss: 0.0062 - accuracy: 0.9987

# %% [markdown]
# ## prediction on unseen data

# %%
input_data = np.array([
    [27.49, 67.81, 55.2, 67.78, 27.49, 67.81, 55.14, 67.87, 27.49, 67.78, 55.12, 67.95],  

])

# input_data = np.array([
#     [30.21, 43.82, 30.16 , 43.05, 30.20 , 43.79, 30.17, 43.05, 30.19, 43.79, 30.17, 43.05],  

# ])



input_data_scaled = scaler.transform(input_data)

input_data2 = input_data_scaled.reshape(1, 3, 4) 

predicted_output = model.predict(input_data2)

# Post-processing
predicted_class = (predicted_output > 0.5).astype(int)
prediction_label = "Normal" if predicted_class == 0 else "Faulty"

print(f"Predicted output: {prediction_label}")
# Out:
# 1/1 [==============================] - 1s 651ms/step
# Predicted output: Faulty

# %%
print(predicted_output)
# Out:
# [[0.99995816]]

# %% [markdown]
# ## Hyperparameter tuning

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_and_train_model(units_1, units_2, dropout_1, dropout_2, learning_rate):
    model = Sequential([
        LSTM(units_1, activation='tanh', input_shape=(3, 4), return_sequences=True),
        Dropout(dropout_1),
        LSTM(units_2, activation='tanh'),
        Dropout(dropout_2),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    
    model.fit(X_train_rnn, y_train, validation_split=0.2, epochs=3, verbose=0)
    
    _, test_accuracy = model.evaluate(X_test_rnn, y_test, verbose=0) 
    
    return model, test_accuracy 

combinations = [
    {'units_1': 128, 'units_2': 64, 'dropout_1': 0.2, 'dropout_2': 0.2, 'learning_rate': 0.001},
    {'units_1': 128, 'units_2': 64, 'dropout_1': 0.3, 'dropout_2': 0.3, 'learning_rate': 0.0001},
    {'units_1': 64, 'units_2': 32, 'dropout_1': 0.2, 'dropout_2': 0.3, 'learning_rate': 0.001},
]

best_accuracy = 0
best_model = None

for params in combinations:
    print(f"Testing combination: {params}")
    model, test_accuracy = build_and_train_model(**params)
    print(f"Test Accuracy: {test_accuracy}")
    
    if test_accuracy > best_accuracy:
        best_accuracy = test_accuracy
        best_model = model

print(f"Best Test Accuracy: {best_accuracy}")
# Out:
# Testing combination: {'units_1': 128, 'units_2': 64, 'dropout_1': 0.2, 'dropout_2': 0.2, 'learning_rate': 0.001}
# Test Accuracy: 0.999216616153717
# Testing combination: {'units_1': 128, 'units_2': 64, 'dropout_1': 0.3, 'dropout_2': 0.3, 'learning_rate': 0.0001}
# Test Accuracy: 0.9989171028137207
# Testing combination: {'units_1': 64, 'units_2': 32, 'dropout_1': 0.2, 'dropout_2': 0.3, 'learning_rate': 0.001}
# Test Accuracy: 0.9990092515945435
# Best Test Accuracy: 0.999216616153717

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = (model.predict(X_test_rnn) > 0.5).astype("int32")

print(classification_report(y_test,y_pred,target_names=["Normal","Faulty"]))
# Out:
# 1357/1357 [==============================] - 4s 2ms/step
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     38357
#       Faulty       1.00      1.00      1.00      5044
#
#     accuracy                           1.00     43401
#    macro avg       1.00      1.00      1.00     43401
# weighted avg       1.00      1.00      1.00     43401

# %% [markdown]
# ## Confustion Matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[38334    23]
#  [   20  5024]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

class_names = ["Normal","Faulty"]

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues",xticklabels=class_names, yticklabels=class_names)
plt.title("Confustion Matrix")
plt.ylabel("Actual Class")
plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# ## Deal with Weight Initialization

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense,Dropout
from tensorflow.keras.initializers import HeNormal, GlorotUniform

model = Sequential([
    LSTM(128,activation='tanh',kernel_initializer=GlorotUniform(),input_shape=(3,4),return_sequences=True),
    Dropout(0.3),
    LSTM(64, activation='tanh',kernel_initializer=GlorotUniform()),
    Dropout(0.3),
    Dense(32,activation='relu',kernel_initializer=HeNormal()),
    Dense(1,activation='sigmoid',kernel_initializer=GlorotUniform())
        
])

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
history = model.fit(X_train_rnn,y_train, epochs=3, class_weight=class_weights_dict)
# Out:
# Epoch 1/3
# 5425/5425 [==============================] - 34s 6ms/step - loss: 0.0396 - accuracy: 0.9865
# Epoch 2/3
# 5425/5425 [==============================] - 31s 6ms/step - loss: 0.0145 - accuracy: 0.9971
# Epoch 3/3
# 5425/5425 [==============================] - 32s 6ms/step - loss: 0.0114 - accuracy: 0.9975

# %%
loss, acc = model.evaluate(X_test_rnn,y_test)
# Out:
# 1357/1357 [==============================] - 5s 3ms/step - loss: 0.0055 - accuracy: 0.9988

# %% [markdown]
# ## Feature Importance by Permutation Importance

# %%
def compute_permutation_importance(model,X, y, metric=accuracy_score):
    baseline_accuracy = metric(y,(model.predict(X) > 0.5).astype(int))
    feature_importance = []
    
    for i in range(X.shape[1]):
        for j in range(X.shape[2]):
            X_permuted = X.copy()
            np.random.shuffle(X_permuted[:, i, j])
        
            accuracy = metric(y,(model.predict(X_permuted) > 0.5).astype(int))
            importance = baseline_accuracy - accuracy
            feature_importance.append(importance)

    return np.array(feature_importance)

importance = compute_permutation_importance(model,X_test_rnn,y_test)
# Out:
# 1357/1357 [==============================] - 5s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step

# %%
print("Feature Importance:", importance)
# Out:
# Feature Importance: [4.69113615e-02 5.87521025e-01 1.74189535e-01 5.63005461e-01
#  3.98608327e-03 4.30450911e-01 1.31909403e-01 2.58980208e-01
#  4.60818875e-05 1.32831041e-01 5.60816571e-02 2.13819958e-02]

# %%
X_test_rnn.shape[2]
# Out:
# 4

# %% [markdown]
# ## visualize feature importance

# %%
features = ['T01', 'H01', 'T02', 'H02', 'T11', 'H11', 'T12', 'H12', 'T21', 'H21', 'T22', 'H22']

importance = compute_permutation_importance(model, X_test_rnn, y_test)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(features, importance)
plt.title('Feature Importance')
plt.ylabel('Importance')
plt.xlabel('Features')
plt.xticks(rotation=45)
plt.show()
# Out:
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step
# 1357/1357 [==============================] - 4s 3ms/step

# %% [markdown]
# ## Visualize weights and biases after training

# %%
for i, layer in enumerate(model.layers):
    print(f"Layer {i} - {layer.name}")
    
    if len(layer.get_weights()) > 0:
        weights = layer.get_weights()
        if "lstm" in layer.name:
            kernel, recurrent_kernel, biases = weights
            print(f"Kernel shape (input-to-hidden):{kernel.shape}")
            print(f"Recurrent kernel shape (hidden-to-hidden):{recurrent_kernel.shape}")
            print(f"Biases shape: {biases.shape}")
        
        else:
            weights, biases = weights
            print(f"Weights shape:{weights.shape}")
            print(f"Biases shape: {biases.shape}")
            
    else:
        print("This layer has no trainable weights.")
# Out:
# Layer 0 - lstm_18
# Kernel shape (input-to-hidden):(4, 512)
# Recurrent kernel shape (hidden-to-hidden):(128, 512)
# Biases shape: (512,)
# Layer 1 - dropout_22
# This layer has no trainable weights.
# Layer 2 - lstm_19
# Kernel shape (input-to-hidden):(128, 256)
# Recurrent kernel shape (hidden-to-hidden):(64, 256)
# Biases shape: (256,)
# Layer 3 - dropout_23
# This layer has no trainable weights.
# Layer 4 - dense_26
# Weights shape:(64, 32)
# Biases shape: (32,)
# Layer 5 - dense_27
# Weights shape:(32, 1)
# Biases shape: (1,)

# %%
layer_name = "dense"

for layer in model.layers:
    if layer.name.startswith(layer_name):
        weights, biases = layer.get_weights()
        
        plt.figure(figsize=(10,6))
        plt.title(f"Weights of Layer: {layer.name}")
        plt.imshow(weights, aspect='auto',cmap="viridis")
        plt.colorbar()
        plt.xlabel("Neurons")
        plt.ylabel("Input Features")
        plt.show()
        
        
        plt.figure(figsize=(10,2))
        plt.title(f"Biases of Layer:{layer.name}")
        plt.bar(np.arange(len(biases)),biases)
        plt.xlabel("Neurons")
        plt.ylabel("Bias Value")
        plt.show()

# %%
lstm_layer = model.layers[0]
kernel, recurrent_kernel, biases = lstm_layer.get_weights()

print("Weights shapes:")
print(f"Kernel (input-to-hidden): {kernel.shape}")
print(f"Recurrent kernel (hidden-to-hidden): {recurrent_kernel.shape}")
print(f"Biases: {biases.shape}")

plt.figure(figsize=(10, 6))
plt.title("LSTM Kernel Weights (Input-to-Hidden)")
plt.imshow(kernel, aspect='auto', cmap='viridis')
plt.colorbar()
plt.xlabel("LSTM Units")
plt.ylabel("Input Features")
plt.show()

plt.figure(figsize=(10, 6))
plt.title("LSTM Recurrent Kernel Weights (Hidden-to-Hidden)")
plt.imshow(recurrent_kernel, aspect='auto', cmap='viridis')
plt.colorbar()
plt.xlabel("LSTM Units")
plt.ylabel("LSTM Units")
plt.show()

# Visualize the biases
plt.figure(figsize=(10, 2))
plt.title("LSTM Biases")
plt.bar(np.arange(len(biases)), biases)
plt.xlabel("Gates (Input, Forget, Output, Candidate)")
plt.ylabel("Bias Value")
plt.show()
# Out:
# Weights shapes:
# Kernel (input-to-hidden): (4, 512)
# Recurrent kernel (hidden-to-hidden): (128, 512)
# Biases: (512,)
